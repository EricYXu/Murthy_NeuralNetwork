# %% [markdown]
# # setup

# %%
import network

import torch
import torch.nn as nn
import torch.nn.functional as F

# Unlike object, with SimpleNamespace you can add and remove attributes.
from types import SimpleNamespace 

import numpy as np

import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import network
#       3 import torch
#       4 import torch.nn as nn
#
# File ~/Documents/Github/Murthy_NeuralNetwork/2_sorted_out_variant_one_layer/network.py:1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# # set the network size, to feed into the 1-layer network class

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

m = 50
n = 100

# Set seed
seed = 1
network.set_random_mode(True, seed)

init_parameters = SimpleNamespace()
init_parameters.m = m # input dimension
init_parameters.n = n # measurement dimension
init_parameters.seed = seed

# the measurement matrix: randomly initialized
init_parameters.W = torch.randn(n,m).to(device)/torch.sqrt(torch.tensor(n))

store_image = True
# Out:
# [Random Mode] Deterministic with seed 1

# %% [markdown]
# ## save the parameters

# %%
import pickle
import os


weight_folder = f'weights/m_{m}_n_{n}_s_{seed}'
os.makedirs(weight_folder, exist_ok=True)

param_path = f'{weight_folder}/init_params.pkl'
with open(param_path, 'wb') as f:
    pickle.dump(init_parameters, f)

# %% [markdown]
# # create the network

# %%
enose_network = network.enose(init_parameters)
print(enose_network.m)
# Out:
# 50

# %% [markdown]
# ## print the architecture of the network

# %%
for name, param in enose_network.named_parameters():
    print(f"{name}: {param.shape}")
# Out:
# fc1.weight: torch.Size([1, 100])
# fc1.bias: torch.Size([1])

# %% [markdown]
# # create the dataset

# %%
num_data=10000
training_frac=0.8
threshold=0.1
x_hat = threshold
num_training = int(num_data*training_frac)

dataset = network.generate_dataset(m, n, device, num_data, training_frac, threshold)

# training dataset
train_conc = dataset.train_conc
train_labels = dataset.train_labels

# test dataset
test_conc = dataset.test_conc
test_labels = dataset.test_labels

test_batch_size = 20

# initial accuracy
initial_accuracy = network.evaluate_random_batch(enose_network, dataset, test_batch_size=20, threshold=0.5)
print(initial_accuracy)
# Out:
# 0.800000011920929

# %% [markdown]
# # optimize the parameters using cross entropy

# %%
criterion = nn.BCELoss()

optimizer = torch.optim.Adam(enose_network.parameters(), lr = 0.001)
lr=0.001

batch_size = 10

steps = 10000
loss_vec = torch.zeros(steps)

test_interval = 50 # to make sure that all the test data are used multiple times
print_interval = 50
test_batch_size = 20
accuracy_vec = torch.zeros(steps // test_interval)

loss_vec, accuracy_vec = network.train_model(
    enose_network,
    criterion,
    optimizer,
    lr,
    train_conc,
    train_labels,
    test_conc,
    test_labels,
    num_data,
    num_training,
    steps,
    batch_size,
    test_interval,
    print_interval,
    test_batch_size,
    device
)
# Out:
# [Step 0] Accuracy: 0.9500 | Train Loss: 0.6646
# [Step 50] Accuracy: 0.9000 | Train Loss: 0.3930
# [Step 100] Accuracy: 1.0000 | Train Loss: 0.8088
# [Step 150] Accuracy: 0.8000 | Train Loss: 0.1144
# [Step 200] Accuracy: 0.8500 | Train Loss: 0.1283
# [Step 250] Accuracy: 0.7500 | Train Loss: 0.3199
# [Step 300] Accuracy: 0.9000 | Train Loss: 0.3683
# [Step 350] Accuracy: 0.9500 | Train Loss: 0.1072
# [Step 400] Accuracy: 0.8500 | Train Loss: 0.9447
# [Step 450] Accuracy: 0.8500 | Train Loss: 0.3263
# [Step 500] Accuracy: 0.8500 | Train Loss: 0.3245
# [Step 550] Accuracy: 0.9500 | Train Loss: 0.8087
# [Step 600] Accuracy: 0.9500 | Train Loss: 0.6215
# [Step 650] Accuracy: 0.9000 | Train Loss: 0.3329
# [Step 700] Accuracy: 0.9500 | Train Loss: 0.1211
# [Step 750] Accuracy: 0.9500 | Train Loss: 0.2784
# [Step 800] Accuracy: 0.9500 | Train Loss: 0.0851
# [Step 850] Accuracy: 0.8000 | Train Loss: 0.4559
# [Step 900] Accuracy: 0.8500 | Train Loss: 0.0995
# [Step 950] Accuracy: 0.9500 | Train Loss: 0.4036
# [Step 1000] Accuracy: 0.8500 | Train Loss: 0.1137
# [Step 1050] Accuracy: 0.9000 | Train Loss: 0.0981
# [Step 1100] Accuracy: 0.8000 | Train Loss: 0.1153
# [Step 1150] Accuracy: 0.9000 | Train Loss: 0.2212
# [Step 1200] Accuracy: 0.9000 | Train Loss: 0.0894
# [Step 1250] Accuracy: 0.7500 | Train Loss: 0.2722
# [Step 1300] Accuracy: 0.9000 | Train Loss: 0.2380
# [Step 1350] Accuracy: 0.9000 | Train Loss: 0.3924
# [Step 1400] Accuracy: 0.9000 | Train Loss: 0.2492
# [Step 1450] Accuracy: 1.0000 | Train Loss: 0.5821
# [Step 1500] Accuracy: 0.9000 | Train Loss: 0.2215
# [Step 1550] Accuracy: 0.9000 | Train Loss: 0.0868
# [Step 1600] Accuracy: 1.0000 | Train Loss: 0.9123
# [Step 1650] Accuracy: 0.9000 | Train Loss: 0.0940
# [Step 1700] Accuracy: 0.8500 | Train Loss: 0.0957
# [Step 1750] Accuracy: 0.9000 | Train Loss: 0.4600
# [Step 1800] Accuracy: 0.9500 | Train Loss: 0.1058
# [Step 1850] Accuracy: 0.9000 | Train Loss: 0.2440
# [Step 1900] Accuracy: 0.9500 | Train Loss: 0.2380
# [Step 1950] Accuracy: 0.9000 | Train Loss: 0.2387
# [Step 2000] Accuracy: 1.0000 | Train Loss: 0.3439
# [Step 2050] Accuracy: 0.8500 | Train Loss: 0.2415
# [Step 2100] Accuracy: 0.9000 | Train Loss: 0.2527
# [Step 2150] Accuracy: 1.0000 | Train Loss: 0.4007
# [Step 2200] Accuracy: 0.8500 | Train Loss: 0.2134
# [Step 2250] Accuracy: 1.0000 | Train Loss: 0.1493
# [Step 2300] Accuracy: 0.9000 | Train Loss: 0.2314
# [Step 2350] Accuracy: 0.9500 | Train Loss: 0.3316
# [Step 2400] Accuracy: 0.9500 | Train Loss: 0.2220
# [Step 2450] Accuracy: 0.9000 | Train Loss: 0.0581
# [Step 2500] Accuracy: 0.9500 | Train Loss: 0.1028
# [Step 2550] Accuracy: 0.9000 | Train Loss: 0.5220
# [Step 2600] Accuracy: 0.8500 | Train Loss: 0.2229
# [Step 2650] Accuracy: 0.8500 | Train Loss: 0.0765
# [Step 2700] Accuracy: 1.0000 | Train Loss: 0.0685
# [Step 2750] Accuracy: 0.7000 | Train Loss: 0.0974
# [Step 2800] Accuracy: 0.8500 | Train Loss: 0.2197
# [Step 2850] Accuracy: 0.8500 | Train Loss: 0.1938
# [Step 2900] Accuracy: 0.9000 | Train Loss: 0.2196
# [Step 2950] Accuracy: 0.9000 | Train Loss: 0.5651
# [Step 3000] Accuracy: 0.9000 | Train Loss: 0.0898
# [Step 3050] Accuracy: 0.9500 | Train Loss: 0.0453
# [Step 3100] Accuracy: 0.9000 | Train Loss: 0.0496
# [Step 3150] Accuracy: 0.9000 | Train Loss: 0.3102
# [Step 3200] Accuracy: 0.8000 | Train Loss: 0.3504
# [Step 3250] Accuracy: 1.0000 | Train Loss: 0.4560
# [Step 3300] Accuracy: 0.9000 | Train Loss: 0.4749
# [Step 3350] Accuracy: 0.9500 | Train Loss: 0.1598
# [Step 3400] Accuracy: 0.9000 | Train Loss: 0.1191
# [Step 3450] Accuracy: 1.0000 | Train Loss: 0.1396
# [Step 3500] Accuracy: 0.9500 | Train Loss: 0.2535
# [Step 3550] Accuracy: 0.8000 | Train Loss: 0.2493
# [Step 3600] Accuracy: 0.9000 | Train Loss: 0.1872
# [Step 3650] Accuracy: 0.9500 | Train Loss: 0.1094
# [Step 3700] Accuracy: 0.9000 | Train Loss: 0.1549
# [Step 3750] Accuracy: 0.9500 | Train Loss: 0.0948
# [Step 3800] Accuracy: 0.9000 | Train Loss: 0.1623
# [Step 3850] Accuracy: 0.9500 | Train Loss: 0.2378
# [Step 3900] Accuracy: 0.8500 | Train Loss: 0.0976
# [Step 3950] Accuracy: 0.8000 | Train Loss: 0.4982
# [Step 4000] Accuracy: 0.9000 | Train Loss: 0.4913
# [Step 4050] Accuracy: 0.9000 | Train Loss: 0.2097
# [Step 4100] Accuracy: 0.9500 | Train Loss: 0.2606
# [Step 4150] Accuracy: 0.9500 | Train Loss: 0.1393
# [Step 4200] Accuracy: 0.9500 | Train Loss: 0.2371
# [Step 4250] Accuracy: 0.9000 | Train Loss: 0.2182
# [Step 4300] Accuracy: 0.9500 | Train Loss: 0.1015
# [Step 4350] Accuracy: 0.9500 | Train Loss: 0.0999
# [Step 4400] Accuracy: 0.9500 | Train Loss: 0.3128
# [Step 4450] Accuracy: 0.9000 | Train Loss: 0.0919
# [Step 4500] Accuracy: 0.9000 | Train Loss: 0.2683
# [Step 4550] Accuracy: 0.9500 | Train Loss: 0.0687
# [Step 4600] Accuracy: 0.9000 | Train Loss: 0.2290
# [Step 4650] Accuracy: 1.0000 | Train Loss: 0.2473
# [Step 4700] Accuracy: 1.0000 | Train Loss: 0.3371
# [Step 4750] Accuracy: 0.9000 | Train Loss: 0.1012
# [Step 4800] Accuracy: 1.0000 | Train Loss: 0.4135
# [Step 4850] Accuracy: 0.8000 | Train Loss: 0.1542
# [Step 4900] Accuracy: 0.9500 | Train Loss: 0.1088
# [Step 4950] Accuracy: 0.9500 | Train Loss: 0.4537
# [Step 5000] Accuracy: 1.0000 | Train Loss: 0.1420
# [Step 5050] Accuracy: 0.7000 | Train Loss: 0.0604
# [Step 5100] Accuracy: 0.8500 | Train Loss: 0.1487
# [Step 5150] Accuracy: 1.0000 | Train Loss: 0.0472
# [Step 5200] Accuracy: 0.9000 | Train Loss: 0.3348
# [Step 5250] Accuracy: 0.9000 | Train Loss: 0.0914
# [Step 5300] Accuracy: 0.9500 | Train Loss: 0.2871
# [Step 5350] Accuracy: 0.9500 | Train Loss: 0.2068
# [Step 5400] Accuracy: 0.9000 | Train Loss: 0.4328
# [Step 5450] Accuracy: 1.0000 | Train Loss: 0.1835
# [Step 5500] Accuracy: 0.9000 | Train Loss: 0.1879
# [Step 5550] Accuracy: 0.9000 | Train Loss: 0.0900
# [Step 5600] Accuracy: 0.9500 | Train Loss: 0.1381
# [Step 5650] Accuracy: 0.9000 | Train Loss: 0.1159
# [Step 5700] Accuracy: 0.9500 | Train Loss: 0.1516
# [Step 5750] Accuracy: 0.9000 | Train Loss: 0.2803
# [Step 5800] Accuracy: 1.0000 | Train Loss: 0.4186
# [Step 5850] Accuracy: 0.9500 | Train Loss: 0.2149
# [Step 5900] Accuracy: 0.9500 | Train Loss: 0.1426
# [Step 5950] Accuracy: 0.8000 | Train Loss: 0.0749
# [Step 6000] Accuracy: 0.9000 | Train Loss: 0.2053
# [Step 6050] Accuracy: 0.9500 | Train Loss: 0.0609
# [Step 6100] Accuracy: 0.7500 | Train Loss: 0.0685
# [Step 6150] Accuracy: 0.8000 | Train Loss: 0.0407
# [Step 6200] Accuracy: 0.9000 | Train Loss: 0.1517
# [Step 6250] Accuracy: 0.9000 | Train Loss: 0.2073
# [Step 6300] Accuracy: 0.7500 | Train Loss: 0.0423
# [Step 6350] Accuracy: 0.9000 | Train Loss: 0.2971
# [Step 6400] Accuracy: 0.8500 | Train Loss: 0.2051
# [Step 6450] Accuracy: 0.8500 | Train Loss: 0.1577
# [Step 6500] Accuracy: 0.9500 | Train Loss: 0.1242
# [Step 6550] Accuracy: 0.8500 | Train Loss: 0.3665
# [Step 6600] Accuracy: 0.8000 | Train Loss: 0.0491
# [Step 6650] Accuracy: 0.9500 | Train Loss: 0.1169
# [Step 6700] Accuracy: 0.9000 | Train Loss: 0.1606
# [Step 6750] Accuracy: 0.9000 | Train Loss: 0.5588
# [Step 6800] Accuracy: 0.9500 | Train Loss: 0.1070
# [Step 6850] Accuracy: 0.9500 | Train Loss: 0.1793
# [Step 6900] Accuracy: 0.9000 | Train Loss: 0.0438
# [Step 6950] Accuracy: 0.8500 | Train Loss: 0.1068
# [Step 7000] Accuracy: 0.9000 | Train Loss: 0.0635
# [Step 7050] Accuracy: 0.9500 | Train Loss: 0.2475
# [Step 7100] Accuracy: 1.0000 | Train Loss: 0.0619
# [Step 7150] Accuracy: 0.9000 | Train Loss: 0.2989
# [Step 7200] Accuracy: 0.9000 | Train Loss: 0.1348
# [Step 7250] Accuracy: 0.9500 | Train Loss: 0.2118
# [Step 7300] Accuracy: 0.9000 | Train Loss: 0.0785
# [Step 7350] Accuracy: 0.9000 | Train Loss: 0.1227
# [Step 7400] Accuracy: 0.9000 | Train Loss: 0.4078
# [Step 7450] Accuracy: 0.9500 | Train Loss: 0.0763
# [Step 7500] Accuracy: 0.7500 | Train Loss: 0.0473
# [Step 7550] Accuracy: 0.8500 | Train Loss: 0.2381
# [Step 7600] Accuracy: 0.8500 | Train Loss: 0.3473
# [Step 7650] Accuracy: 1.0000 | Train Loss: 0.0797
# [Step 7700] Accuracy: 1.0000 | Train Loss: 0.0814
# [Step 7750] Accuracy: 1.0000 | Train Loss: 0.0525
# [Step 7800] Accuracy: 0.8500 | Train Loss: 0.1041
# [Step 7850] Accuracy: 0.8500 | Train Loss: 0.1797
# [Step 7900] Accuracy: 1.0000 | Train Loss: 0.2267
# [Step 7950] Accuracy: 1.0000 | Train Loss: 0.0552
# [Step 8000] Accuracy: 0.9500 | Train Loss: 0.0831
# [Step 8050] Accuracy: 0.9500 | Train Loss: 0.0443
# [Step 8100] Accuracy: 0.8500 | Train Loss: 0.1371
# [Step 8150] Accuracy: 0.9500 | Train Loss: 0.1330
# [Step 8200] Accuracy: 0.9500 | Train Loss: 0.2204
# [Step 8250] Accuracy: 0.9000 | Train Loss: 0.0681
# [Step 8300] Accuracy: 0.9000 | Train Loss: 0.2333
# [Step 8350] Accuracy: 0.9500 | Train Loss: 0.1707
# [Step 8400] Accuracy: 0.9000 | Train Loss: 0.2593
# [Step 8450] Accuracy: 0.9500 | Train Loss: 0.0638
# [Step 8500] Accuracy: 0.8000 | Train Loss: 0.3337
# [Step 8550] Accuracy: 0.9500 | Train Loss: 0.0637
# [Step 8600] Accuracy: 0.9000 | Train Loss: 0.0455
# [Step 8650] Accuracy: 1.0000 | Train Loss: 0.1231
# [Step 8700] Accuracy: 0.9000 | Train Loss: 0.5949
# [Step 8750] Accuracy: 0.8500 | Train Loss: 0.2022
# [Step 8800] Accuracy: 0.8500 | Train Loss: 0.0704
# [Step 8850] Accuracy: 0.8500 | Train Loss: 0.0684
# [Step 8900] Accuracy: 0.8500 | Train Loss: 0.1965
# [Step 8950] Accuracy: 1.0000 | Train Loss: 0.2105
# [Step 9000] Accuracy: 1.0000 | Train Loss: 0.3932
# [Step 9050] Accuracy: 0.9500 | Train Loss: 0.3761
# [Step 9100] Accuracy: 0.9500 | Train Loss: 0.1573
# [Step 9150] Accuracy: 1.0000 | Train Loss: 0.0610
# [Step 9200] Accuracy: 0.9500 | Train Loss: 0.0648
# [Step 9250] Accuracy: 0.9000 | Train Loss: 0.3900
# [Step 9300] Accuracy: 0.8500 | Train Loss: 0.2143
# [Step 9350] Accuracy: 0.9000 | Train Loss: 0.1213
# [Step 9400] Accuracy: 0.9000 | Train Loss: 0.1103
# [Step 9450] Accuracy: 0.9500 | Train Loss: 0.3406
# [Step 9500] Accuracy: 0.9000 | Train Loss: 0.1124
# [Step 9550] Accuracy: 0.8000 | Train Loss: 0.2117
# [Step 9600] Accuracy: 1.0000 | Train Loss: 0.0645
# [Step 9650] Accuracy: 0.9000 | Train Loss: 0.2144
# [Step 9700] Accuracy: 0.8500 | Train Loss: 0.1406
# [Step 9750] Accuracy: 1.0000 | Train Loss: 0.0707
# [Step 9800] Accuracy: 0.9500 | Train Loss: 0.2452
# [Step 9850] Accuracy: 0.8500 | Train Loss: 0.0432
# [Step 9900] Accuracy: 1.0000 | Train Loss: 0.1178
# [Step 9950] Accuracy: 0.9500 | Train Loss: 0.2268

# %% [markdown]
# ## save the trained parameters

# %%
# to save the model weights
torch.save(enose_network.state_dict(), f"{weight_folder}/model_weights.pth")

# %%
accuracy_vec
# Out:
# tensor([0.9500, 0.9000, 1.0000, 0.8000, 0.8500, 0.7500, 0.9000, 0.9500, 0.8500,
#         0.8500, 0.8500, 0.9500, 0.9500, 0.9000, 0.9500, 0.9500, 0.9500, 0.8000,
#         0.8500, 0.9500, 0.8500, 0.9000, 0.8000, 0.9000, 0.9000, 0.7500, 0.9000,
#         0.9000, 0.9000, 1.0000, 0.9000, 0.9000, 1.0000, 0.9000, 0.8500, 0.9000,
#         0.9500, 0.9000, 0.9500, 0.9000, 1.0000, 0.8500, 0.9000, 1.0000, 0.8500,
#         1.0000, 0.9000, 0.9500, 0.9500, 0.9000, 0.9500, 0.9000, 0.8500, 0.8500,
#         1.0000, 0.7000, 0.8500, 0.8500, 0.9000, 0.9000, 0.9000, 0.9500, 0.9000,
#         0.9000, 0.8000, 1.0000, 0.9000, 0.9500, 0.9000, 1.0000, 0.9500, 0.8000,
#         0.9000, 0.9500, 0.9000, 0.9500, 0.9000, 0.9500, 0.8500, 0.8000, 0.9000,
#         0.9000, 0.9500, 0.9500, 0.9500, 0.9000, 0.9500, 0.9500, 0.9500, 0.9000,
#         0.9000, 0.9500, 0.9000, 1.0000, 1.0000, 0.9000, 1.0000, 0.8000, 0.9500,
#         0.9500, 1.0000, 0.7000, 0.8500, 1.0000, 0.9000, 0.9000, 0.9500, 0.9500,
#         0.9000, 1.0000, 0.9000, 0.9000, 0.9500, 0.9000, 0.9500, 0.9000, 1.0000,
#         0.9500, 0.9500, 0.8000, 0.9000, 0.9500, 0.7500, 0.8000, 0.9000, 0.9000,
#         0.7500, 0.9000, 0.8500, 0.8500, 0.9500, 0.8500, 0.8000, 0.9500, 0.9000,
#         0.9000, 0.9500, 0.9500, 0.9000, 0.8500, 0.9000, 0.9500, 1.0000, 0.9000,
#         0.9000, 0.9500, 0.9000, 0.9000, 0.9000, 0.9500, 0.7500, 0.8500, 0.8500,
#         1.0000, 1.0000, 1.0000, 0.8500, 0.8500, 1.0000, 1.0000, 0.9500, 0.9500,
#         0.8500, 0.9500, 0.9500, 0.9000, 0.9000, 0.9500, 0.9000, 0.9500, 0.8000,
#         0.9500, 0.9000, 1.0000, 0.9000, 0.8500, 0.8500, 0.8500, 0.8500, 1.0000,
#         1.0000, 0.9500, 0.9500, 1.0000, 0.9500, 0.9000, 0.8500, 0.9000, 0.9000,
#         0.9500, 0.9000, 0.8000, 1.0000, 0.9000, 0.8500, 1.0000, 0.9500, 0.8500,
#         1.0000, 0.9500])

# %% [markdown]
# ## save mean accuracy, to compare with the accuracy after weight pertubation

# %%
num_step = len(accuracy_vec)
mean_accuracy = torch.mean(accuracy_vec[num_step//2:-1])

param_path = f'{weight_folder}/mean_accuracy.pkl'
with open(param_path, 'wb') as f:
    pickle.dump(mean_accuracy, f)
    
print(num_step)
mean_accuracy
# Out:
# 200
# tensor(0.9101)

# %% [markdown]
# # plot the training loss and test accuracy

# %%
# Plot the loss curve and save (optional)

import matplotlib.pyplot as plt
import os

plt.plot(loss_vec)
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training Loss Over Time")
# Make sure the folder exists
if store_image:
    folder = f'figures/m_{m}_n_{n}_s_{seed}'
    os.makedirs(folder, exist_ok=True)
    plt.savefig(f"{folder}/loss.pdf") 
plt.show()

# %%
# Plot the test accuracy curve

import matplotlib.pyplot as plt

# mean_accuracy = torch.mean()

plt.figure(figsize=(8, 4))
plt.plot(torch.arange(0, steps, 50), accuracy_vec, label='Test Accuracy')
plt.xlabel("Training Step")
plt.ylabel("Accuracy")
plt.title(f"Odor Detection Accuracy Over Training, with a mean of {mean_accuracy:.3f}")
plt.ylim(0, 1.05)
# plt.grid(True)
plt.legend()
plt.tight_layout()
if store_image:
    plt.savefig(f"{folder}/accuracy.pdf")

plt.show()

# %% [markdown]
# # plot the weight matrices

# %%
import torch
import matplotlib.pyplot as plt
W = enose_network.W.cpu().numpy()
# Plot using imshow
plt.figure(figsize=(15, 5))
plt.imshow(W, cmap='RdBu', interpolation='nearest')
plt.colorbar(label='Value')
plt.title(r'$\bf W$')
plt.xlabel('Columns')
plt.ylabel('Rows')
if store_image:
    plt.savefig(f"{folder}/W.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## plot the matrices

# %%
enose_network.fc1.bias
# Out:
# Parameter containing:
# tensor([0.1300], device='mps:0', requires_grad=True)

# %%
import torch
import matplotlib.pyplot as plt

W1 = enose_network.fc1.weight.detach().cpu().numpy()
b1 = enose_network.fc1.bias.detach().cpu().numpy()
print(b1.size)

W_h = W1 @ W
x1_hat_dagger = -b1[0]/W_h[0,0].item()
print(x1_hat_dagger)

# Plot using imshow
plt.figure(figsize=(25, 5))
plt.imshow(W1, cmap='RdBu', interpolation='nearest')
plt.colorbar(label='Value')
plt.title(r'$\bf W_1$')
plt.xlabel('Columns')
plt.ylabel('Rows')
if store_image:
    plt.savefig(f"{folder}/W1.pdf", bbox_inches='tight')
plt.show()
# Out:
# 1
# -0.02111214400245365

# %%
import torch
import matplotlib.pyplot as plt

# Plot using imshow
plt.figure(figsize=(25, 5))
plt.imshow(W_h , cmap='Reds', interpolation='nearest')
plt.colorbar(label='Value')
plt.title(r'$\bf W_1 W$')
plt.xlabel('Columns')
plt.ylabel('Rows')
if store_image:
    plt.savefig(f"{folder}/W_h.pdf")
# plt.savefig("figures/W_h.pdf")
plt.show()
plt.close()

# to verify that the first element dominates
print(W_h[0])
# Out:
# [ 6.1597304e+00  5.4484481e-01  2.2010355e-01  4.9213916e-01
#   1.3618195e-01  5.6215309e-02 -1.5830420e-01 -3.6957461e-01
#  -4.0832575e-02  3.6013561e-01 -7.4066883e-01 -1.4259686e-01
#  -3.1934673e-01 -5.5612318e-02  1.8242872e-01  3.8385823e-01
#  -4.0084761e-02  3.1774826e-03 -6.9922499e-02  1.7093734e-01
#  -5.9168532e-02 -3.3370551e-02  1.6744456e-01  5.3074998e-01
#   3.0598164e-02  4.5076799e-01  3.0650494e-01 -1.3242993e-01
#  -9.7904772e-02  4.1026318e-01 -1.8624239e-01  7.8410193e-02
#  -5.2922428e-01 -7.3130167e-01 -6.0259563e-01  1.1772072e-01
#  -3.5971096e-01  2.2075140e-01  3.4780991e-01 -2.2449027e-01
#  -1.4917311e-01 -6.8359151e-02  8.2337774e-02 -1.7651790e-01
#  -3.5448420e-01  2.9752793e-02  5.2967840e-01 -4.0581416e-02
#  -6.3825719e-02  8.2019620e-02]

# %% [markdown]
# # plot the simplified 1-D curve, since the first element dominates

# %%
x_hat = threshold
print(x_hat)
print(x1_hat_dagger)
# Out:
# 0.1
# -0.021112155313290328

# %%
# x = torch.linspace(0, 1, 200)
x = torch.linspace(-1, 1, 200)

y = torch.sigmoid( W_h[0][0]*x + b1 )
y_2 = torch.sigmoid( 200*(x - x_hat) )
plt.plot(x, y, label =' learned function')
plt.plot(x, y_2, label = ' desired shape')
plt.axhline(y=0.5, color='gray', linestyle='--', linewidth=1)
plt.plot(x_hat, 0.5, 'o', color='red', label=r'$\hat{x}_1$')
plt.plot(x1_hat_dagger, 0.5, 'o', color='purple', label=r'$\hat{x}_1^\dagger$')


plt.title(fr'$\hat{{x}}_1 = {x_hat:.2f} $, with the learned $\hat{{x}}_1^\dagger = {x1_hat_dagger:.4f} $')
plt.xlabel(r'$x_1$')
plt.ylabel(r'$\operatorname{Sigmoid}\left[ W_{\operatorname{tt},1} x_1 + b_1 ) \right]$')
plt.legend()
plt.grid(True)
if store_image:
    plt.savefig(f"{folder}/pickup_first_dim.pdf", bbox_inches='tight')
plt.show()

# %% [markdown]
# ## verify that the analytical full expression is correct; compare the full expression versus the simplified 1-D expression

# %%
# the test dataset
test_idx = torch.randint(0, num_data - num_training, (test_batch_size,))
x_test = test_conc[:, test_idx]
y_test = test_labels[test_idx].view(-1, 1).float()

# %%
## ===== to check the analytical expression matches with the network expression =====

W_h_tensor = torch.tensor(W_h, dtype=torch.float32, device=x_test.device)
bias_final = torch.tensor(b1, dtype=torch.float32, device=x_test.device)

# the network expression
with torch.no_grad():
    enose_network.eval()
    pred = enose_network(x_test)
    predicted_labels = (pred > 0.5).float()
    accuracy = (predicted_labels == y_test).float().mean().item()
    # accuracy_vec[ steps // test_interval] = accuracy
    print(f"Test Accuracy = {accuracy:.4f}")

print(pred.mT)

# the analytical expression
out1 = torch.sigmoid(W_h_tensor @ x_test + bias_final)  # shape: [output_dim, num_samples]
out1 = out1[0]
print(out1)
# Out:
# Test Accuracy = 0.9500
# tensor([[0.7924, 0.9336, 0.9541, 0.9028, 0.9365, 0.8498, 0.9219, 0.9672, 0.9515,
#          0.5628, 0.6947, 0.9977, 0.9605, 0.9949, 0.8596, 0.9042, 0.7268, 0.8277,
#          0.8945, 0.9909]], device='mps:0')
# tensor([0.7924, 0.9336, 0.9541, 0.9028, 0.9365, 0.8498, 0.9219, 0.9672, 0.9515,
#         0.5628, 0.6947, 0.9977, 0.9605, 0.9949, 0.8596, 0.9042, 0.7268, 0.8277,
#         0.8945, 0.9909], device='mps:0')

# %%
out2 = torch.sigmoid(W_h_tensor[0][0] * x_test[0, :] + bias_final)  # shape: [num_samples]
out3 = torch.sigmoid(W_h_tensor[0][0] * (x_test[0, :] - x1_hat_dagger) )  # shape: [num_samples]
out4 = torch.sigmoid(W_h_tensor[0][0] * (x_test[0, :] - x_hat) )  # shape: [num_samples]

accr_1 = ((out1 > 0.5).float().T == y_test.squeeze()).float().mean().item()
accr_2 = ((out2 > 0.5).float().T == y_test.squeeze()).float().mean().item()
# Out:
# /var/folders/c6/4pyqhs6s5dd_s0wwq651cmmr0000gn/T/ipykernel_62733/4066574986.py:5: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3687.)
#   accr_1 = ((out1 > 0.5).float().T == y_test.squeeze()).float().mean().item()

# %%
import torch
import matplotlib.pyplot as plt

# Plot comparison
plt.figure(figsize=(10, 4))
plt.plot(out1.cpu(), label=fr'$\operatorname{{Sigmoid}}\left[\bf W_2 (W_1 Wx +b_1)+b_2 \right],\ \operatorname{{Accuracy: }} {accr_1:.2f} $')
plt.plot(out2.cpu(), label=fr'$\operatorname{{Sigmoid}}\left(W_{{tt,1}} x_1 + W_2b_1+b_2 \right),\ \operatorname{{Accuracy: }} {accr_2:.2f} $')
# plt.plot(out3.cpu(), label=fr'$\operatorname{{Sigmoid}}\left[\bf W_2 (W_1 Wx +b_1)+b_2 \right],\ \operatorname{{Accuracy: }} {accr_1:.2f} $')
# plt.plot(out4.cpu(), label=fr'$\operatorname{{Sigmoid}}\left(W_{{tt,1}} x_1 + W_2b_1+b_2 \right),\ \operatorname{{Accuracy: }} {accr_2:.2f} $')
# plt.plot(log_out2.cpu(), label=r'$\operatorname{Sigmoid}$', linestyle='--')
plt.plot(y_test.cpu(), label = 'True labels', linestyle='none', marker='.', markersize = 20, color='plum')
plt.title("Output Comparison")
plt.xlabel("Sample Index")
plt.xticks(ticks=range(0, len(y_test)+1,5), labels=range(0, len(y_test)+1,5))
plt.ylabel("Sigmoid output")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
if store_image:
    plt.savefig(f"{folder}/Output_Comparison.pdf", bbox_inches='tight')
plt.show()
